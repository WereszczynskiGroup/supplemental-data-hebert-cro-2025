# %%
# Define your 8 patterns here
patterns = [
    "_17",
    "_21",
    "_22",
    "_26",
    "_83",
    "_87",
    "_88",
    "_92"
]

input_file = "WT_Mhbond.dat"      # Change to your file path
output_file = "WT_Mhbond_mut.dat"  # Output file name

# Compile patterns for efficient searching
import re
compiled_patterns = [re.compile(p) for p in patterns]

with open(input_file, "r") as infile, open(output_file, "w") as outfile:
    # Read and write the first line unconditionally
    first_line = infile.readline()
    outfile.write(first_line)

    # Now filter the rest of the lines
    for line in infile:
        if any(p.search(line) for p in compiled_patterns):
            outfile.write(line)

input_file = "WTdimhbond.dat"      # Change to your file path
output_file = "WTdimhbond_mut.dat"  # Output file name

# Compile patterns for efficient searching
import re
compiled_patterns = [re.compile(p) for p in patterns]

with open(input_file, "r") as infile, open(output_file, "w") as outfile:
    # Read and write the first line unconditionally
    first_line = infile.readline()
    outfile.write(first_line)

    # Now filter the rest of the lines
    for line in infile:
        if any(p.search(line) for p in compiled_patterns):
            outfile.write(line)

input_file = "A3_Mhbond.dat"      # Change to your file path
output_file = "A3_Mhbond_mut.dat"  # Output file name

# Compile patterns for efficient searching
import re
compiled_patterns = [re.compile(p) for p in patterns]

with open(input_file, "r") as infile, open(output_file, "w") as outfile:
    # Read and write the first line unconditionally
    first_line = infile.readline()
    outfile.write(first_line)

    # Now filter the rest of the lines
    for line in infile:
        if any(p.search(line) for p in compiled_patterns):
            outfile.write(line)

input_file = "A3dimhbond.dat"      # Change to your file path
output_file = "A3dimhbond_mut.dat"  # Output file name

# Compile patterns for efficient searching
import re
compiled_patterns = [re.compile(p) for p in patterns]

with open(input_file, "r") as infile, open(output_file, "w") as outfile:
    # Read and write the first line unconditionally
    first_line = infile.readline()
    outfile.write(first_line)

    # Now filter the rest of the lines
    for line in infile:
        if any(p.search(line) for p in compiled_patterns):
            outfile.write(line)

input_file = "A8_Mhbond.dat"      # Change to your file path
output_file = "A8_Mhbond_mut.dat"  # Output file name

# Compile patterns for efficient searching
import re
compiled_patterns = [re.compile(p) for p in patterns]

with open(input_file, "r") as infile, open(output_file, "w") as outfile:
    # Read and write the first line unconditionally
    first_line = infile.readline()
    outfile.write(first_line)

    # Now filter the rest of the lines
    for line in infile:
        if any(p.search(line) for p in compiled_patterns):
            outfile.write(line)

input_file = "A8dimhbond.dat"      # Change to your file path
output_file = "A8dimhbond_mut.dat"  # Output file name

# Compile patterns for efficient searching
import re
compiled_patterns = [re.compile(p) for p in patterns]

with open(input_file, "r") as infile, open(output_file, "w") as outfile:
    # Read and write the first line unconditionally
    first_line = infile.readline()
    outfile.write(first_line)

    # Now filter the rest of the lines
    for line in infile:
        if any(p.search(line) for p in compiled_patterns):
            outfile.write(line)

# %%
# Define your 8 patterns here
patterns = [
    "_17",
    "_21",
    "_22",
    "_26",
    "_76",
    "_80",
    "_81",
    "_85"
]
input_file = "WTr_Mhbond.dat"      # Change to your file path
output_file = "WTr_Mhbond_mut.dat"  # Output file name

# Compile patterns for efficient searching
import re
compiled_patterns = [re.compile(p) for p in patterns]

with open(input_file, "r") as infile, open(output_file, "w") as outfile:
    # Read and write the first line unconditionally
    first_line = infile.readline()
    outfile.write(first_line)

    # Now filter the rest of the lines
    for line in infile:
        if any(p.search(line) for p in compiled_patterns):
            outfile.write(line)

input_file = "WTrdimhbond.dat"      # Change to your file path
output_file = "WTrdimhbond_mut.dat"  # Output file name

# Compile patterns for efficient searching
import re
compiled_patterns = [re.compile(p) for p in patterns]

with open(input_file, "r") as infile, open(output_file, "w") as outfile:
    # Read and write the first line unconditionally
    first_line = infile.readline()
    outfile.write(first_line)

    # Now filter the rest of the lines
    for line in infile:
        if any(p.search(line) for p in compiled_patterns):
            outfile.write(line)

input_file = "T3_Mhbond.dat"      # Change to your file path
output_file = "T3_Mhbond_mut.dat"  # Output file name

# Compile patterns for efficient searching
import re
compiled_patterns = [re.compile(p) for p in patterns]

with open(input_file, "r") as infile, open(output_file, "w") as outfile:
    # Read and write the first line unconditionally
    first_line = infile.readline()
    outfile.write(first_line)

    # Now filter the rest of the lines
    for line in infile:
        if any(p.search(line) for p in compiled_patterns):
            outfile.write(line)

input_file = "T3dimhbond.dat"      # Change to your file path
output_file = "T3dimhbond_mut.dat"  # Output file name

# Compile patterns for efficient searching
import re
compiled_patterns = [re.compile(p) for p in patterns]

with open(input_file, "r") as infile, open(output_file, "w") as outfile:
    # Read and write the first line unconditionally
    first_line = infile.readline()
    outfile.write(first_line)

    # Now filter the rest of the lines
    for line in infile:
        if any(p.search(line) for p in compiled_patterns):
            outfile.write(line)

input_file = "T8_Mhbond.dat"      # Change to your file path
output_file = "T8_Mhbond_mut.dat"  # Output file name

# Compile patterns for efficient searching
import re
compiled_patterns = [re.compile(p) for p in patterns]

with open(input_file, "r") as infile, open(output_file, "w") as outfile:
    # Read and write the first line unconditionally
    first_line = infile.readline()
    outfile.write(first_line)

    # Now filter the rest of the lines
    for line in infile:
        if any(p.search(line) for p in compiled_patterns):
            outfile.write(line)

input_file = "T8dimhbond.dat"      # Change to your file path
output_file = "T8dimhbond_mut.dat"  # Output file name

# Compile patterns for efficient searching
import re
compiled_patterns = [re.compile(p) for p in patterns]

with open(input_file, "r") as infile, open(output_file, "w") as outfile:
    # Read and write the first line unconditionally
    first_line = infile.readline()
    outfile.write(first_line)

    # Now filter the rest of the lines
    for line in infile:
        if any(p.search(line) for p in compiled_patterns):
            outfile.write(line)

# %%
# Define your 8 patterns here
patterns = [
    "_81",
    "_85",
    "_86",
    "_90",
    "_147",
    "_151",
    "_152",
    "_156"
]
input_file = "WTdnahbond.dat"      # Change to your file path
output_file = "WTdnahbond_mut.dat"  # Output file name

# Compile patterns for efficient searching
import re
compiled_patterns = [re.compile(p) for p in patterns]

with open(input_file, "r") as infile, open(output_file, "w") as outfile:
    # Read and write the first line unconditionally
    first_line = infile.readline()
    outfile.write(first_line)

    # Now filter the rest of the lines
    for line in infile:
        if any(p.search(line) for p in compiled_patterns):
            outfile.write(line)

input_file = "A3dnahbond.dat"      # Change to your file path
output_file = "A3dnahbond_mut.dat"  # Output file name

# Compile patterns for efficient searching
import re
compiled_patterns = [re.compile(p) for p in patterns]

with open(input_file, "r") as infile, open(output_file, "w") as outfile:
    # Read and write the first line unconditionally
    first_line = infile.readline()
    outfile.write(first_line)

    # Now filter the rest of the lines
    for line in infile:
        if any(p.search(line) for p in compiled_patterns):
            outfile.write(line)

input_file = "A8dnahbond.dat"      # Change to your file path
output_file = "A8dnahbond_mut.dat"  # Output file name

# Compile patterns for efficient searching
import re
compiled_patterns = [re.compile(p) for p in patterns]

with open(input_file, "r") as infile, open(output_file, "w") as outfile:
    # Read and write the first line unconditionally
    first_line = infile.readline()
    outfile.write(first_line)

    # Now filter the rest of the lines
    for line in infile:
        if any(p.search(line) for p in compiled_patterns):
            outfile.write(line)

# %%
# Define your 8 patterns here
patterns = [
    "_81",
    "_85",
    "_86",
    "_90",
    "_140",
    "_144",
    "_145",
    "_149"
]

input_file = "WTrdnahbond.dat"      # Change to your file path
output_file = "WTrdnahbond_mut.dat"  # Output file name

# Compile patterns for efficient searching
import re
compiled_patterns = [re.compile(p) for p in patterns]

with open(input_file, "r") as infile, open(output_file, "w") as outfile:
    # Read and write the first line unconditionally
    first_line = infile.readline()
    outfile.write(first_line)

    # Now filter the rest of the lines
    for line in infile:
        if any(p.search(line) for p in compiled_patterns):
            outfile.write(line)

input_file = "T3dnahbond.dat"      # Change to your file path
output_file = "T3dnahbond_mut.dat"  # Output file name

# Compile patterns for efficient searching
import re
compiled_patterns = [re.compile(p) for p in patterns]

with open(input_file, "r") as infile, open(output_file, "w") as outfile:
    # Read and write the first line unconditionally
    first_line = infile.readline()
    outfile.write(first_line)

    # Now filter the rest of the lines
    for line in infile:
        if any(p.search(line) for p in compiled_patterns):
            outfile.write(line)

input_file = "T8dnahbond.dat"      # Change to your file path
output_file = "T8dnahbond_mut.dat"  # Output file name

# Compile patterns for efficient searching
import re
compiled_patterns = [re.compile(p) for p in patterns]

with open(input_file, "r") as infile, open(output_file, "w") as outfile:
    # Read and write the first line unconditionally
    first_line = infile.readline()
    outfile.write(first_line)

    # Now filter the rest of the lines
    for line in infile:
        if any(p.search(line) for p in compiled_patterns):
            outfile.write(line)
