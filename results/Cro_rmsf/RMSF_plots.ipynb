# %%
# Code in this notebook was written by Ryan Hebert
# The data used in this notebook was collected by analyzing simulations run by Ryan Hebert and Alex Perez

import matplotlib.pyplot as plt
import numpy as np
font = {'family': 'sans-serif',
        'color':  'black',
        'weight': 'normal',
        'size': 10,
        }

# %%
x1,y1,yerr1 = np.loadtxt("./RMSF/WT_M_allfluct.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))		
xx1,yy1,yyerr1 = np.loadtxt("./RMSF/WTdim_sub1rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))
xxx1,yyy1,yyyerr1 = np.loadtxt("./RMSF/WTdna_sub1rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))	

x2,y2,yerr2 = np.loadtxt("./RMSF/A3_M_allfluct.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))	
xx2,yy2,yyerr2 = np.loadtxt("./RMSF/A3dim_sub1rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))	
xxx2,yyy2,yyyerr2 = np.loadtxt("./RMSF/A3dna_sub1rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))	

x3,y3,yerr3 = np.loadtxt("./RMSF/A8_M_allfluct.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))	
xx3,yy3,yyerr3 = np.loadtxt("./RMSF/A8dim_sub1rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))	
xxx3,yyy3,yyyerr3 = np.loadtxt("./RMSF/A8dna_sub1rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))

x4,y4,yerr4 = np.loadtxt("./RMSF/WTr_M_allfluct.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))		
xx4,yy4,yyerr4 = np.loadtxt("./RMSF/WTrdim_sub1rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))	
xxx4,yyy4,yyyerr4 = np.loadtxt("./RMSF/WTrdna_sub1rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))	

x5,y5,yerr5 = np.loadtxt("./RMSF/T3_M_allfluct.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))	
xx5,yy5,yyerr5 = np.loadtxt("./RMSF/T3dim_sub1rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))	
xxx5,yyy5,yyyerr5 = np.loadtxt("./RMSF/T3dna_sub1rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))	

x6,y6,yerr6 = np.loadtxt("./RMSF/T8_M_allfluct.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))	
xx6,yy6,yyerr6 = np.loadtxt("./RMSF/T8dim_sub1rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))	
xxx6,yyy6,yyyerr6 = np.loadtxt("./RMSF/T8dna_sub1rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))

# %%
# For presentation

fig, axs = plt.subplots(3,3, figsize=(6.5,5.6), sharey=True, sharex=True)

axs[0,0].plot(x1,y1, alpha=0.5, marker=".", lw=2, label='Full Length', color='black')
axs[0,0].fill_between(x1, y1-(yerr1/2.2), y1+(yerr1/2.2), alpha=0.3, color='black')

axs[0,1].plot(x2,y2, alpha=0.5, marker=".", lw=2, label='Full Length', color='black')
axs[0,1].fill_between(x2, y2-(yerr2/2.2), y2+(yerr2/2.2), alpha=0.3, color='black')

axs[0,2].plot(x3,y3, alpha=0.5, marker=".", lw=2, label='Full Length', color='black')
axs[0,2].fill_between(x3, y3-(yerr3/2.2), y3+(yerr3/2.2), alpha=0.3, color='black')
axs[0,0].set_xlim(0,66)
axs[0,0].set_ylim(0,18)
axs[0,0].set_yticks(np.arange(0,19,3))

axs[0,0].set_title('Wild Type')
axs[0,2].set_title('Act 8')
axs[0,0].set_xticks(np.arange(0,70,10))
axs[0,1].set_xticks(np.arange(0,70,10))
axs[0,2].set_xticks(np.arange(0,70,10))

axs[1,0].plot(xx1,yy1, alpha=0.5, marker=".", lw=2, label='Full Length', color='black')
axs[1,0].fill_between(xx1, yy1-(yyerr1/2.2), yy1+(yyerr1/2.2), alpha=0.3, color='black')
axs[1,0].set_xlim(0,66)
axs[1,1].plot(xx2,yy2, alpha=0.5, marker=".", lw=2, label='Full Length', color='black')
axs[1,1].fill_between(xx2, yy2-(yyerr2/2.2), yy2+(yyerr2/2.2), alpha=0.3, color='black')
axs[1,0].set_xlim(0,66)
axs[1,2].plot(xx3,yy3, alpha=0.5, marker=".", lw=2, label='Full Length', color='black')
axs[1,2].fill_between(xx3, yy3-(yyerr3/2.2), yy3+(yyerr3/2.2), alpha=0.3, color='black')
axs[1,0].set_ylabel('RMSF ($\AA$)')
axs[1,0].set_xticks(np.arange(0,70,10))

axs[2,0].plot(xxx1,yyy1, alpha=0.5, marker=".", lw=2, label='Full Length', color='black')
axs[2,0].fill_between(xxx1, yyy1-(yyyerr1/2.2), yyy1+(yyyerr1/2.2), alpha=0.3, color='black')
axs[2,0].set_xlim(0,66)
axs[2,1].plot(xxx2,yyy2, alpha=0.5, marker=".", lw=2, label='Full Length', color='black')
axs[2,1].fill_between(xxx2, yyy2-(yyyerr2/2.2), yyy2+(yyyerr2/2.2), alpha=0.3, color='black')
axs[2,0].set_xticks(np.arange(0,70,10))
axs[2,2].plot(xxx3,yyy3, alpha=0.5, marker=".", lw=2, label='Full Length', color='black')
axs[2,2].fill_between(xxx3, yyy3-(yyyerr3/2.2), yyy3+(yyyerr3/2.2), alpha=0.3, color='black')
axs[2,0].set_xlabel('Residue')

axs[0,0].plot(x4,y4, alpha=0.5, marker=".", lw=2, label='Truncated', color='red')
axs[0,0].fill_between(x4, y4-(yerr4/2.2), y4+(yerr4/2.2), alpha=0.3, color='red')

axs[0,1].plot(x5,y5, alpha=0.5, marker=".", lw=2, label='Act 3', color='red')
axs[0,1].fill_between(x5, y5-(yerr5/2.2), y5+(yerr5/2.2), alpha=0.3, color='red')

axs[0,2].plot(x6,y6, alpha=0.5, marker=".", lw=2, label='Act 8', color='red')
axs[0,2].fill_between(x6, y6-(yerr6/2.2), y6+(yerr6/2.2), alpha=0.3, color='red')
axs[0,1].set_xlim(0,66)
axs[0,1].set_ylim(0,22)
axs[0,1].set_yticks(np.arange(0,22,3))
axs[0,1].set_title('Act 3')

axs[1,0].plot(xx4[0:58],yy4[0:58], alpha=0.5, marker=".", lw=2, label='Wild Type', color='red')
axs[1,0].fill_between(xx4[0:58], yy4[0:58]-(yyerr4[0:58]/2.2), yy4[0:58]+(yyerr4[0:58]/2.2), alpha=0.3, color='red')
axs[1,1].set_xlim(0,66)
axs[1,1].plot(xx5[0:58],yy5[0:58], alpha=0.5, marker=".", lw=2, label='Act 3', color='red')
axs[1,1].fill_between(xx5[0:58], yy5[0:58]-(yyerr5[0:58]/2.2), yy5[0:58]+(yyerr5[0:58]/2.2), alpha=0.3, color='red')

axs[1,2].plot(xx6[0:58],yy6[0:58], alpha=0.5, marker=".", lw=2, label='Act 8', color='red')
axs[1,2].fill_between(xx6[0:58], yy6[0:58]-(yyerr6[0:58]/2.2), yy6[0:58]+(yyerr6[0:58]/2.2), alpha=0.3, color='red')

axs[2,0].plot(xxx4[0:58],yyy4[0:58], alpha=0.5, marker=".", lw=2, label='Wild Type', color='red')
axs[2,0].fill_between(xxx4[0:58], yyy4[0:58]-(yyyerr4[0:58]/2.2), yyy4[0:58]+(yyyerr4[0:58]/2.2), alpha=0.3, color='red')

axs[2,1].plot(xxx5,yyy5, alpha=0.5, marker=".", lw=2, label='Truncated', color='red')
axs[2,1].fill_between(xxx5, yyy5-(yyyerr5/2.2), yyy5+(yyyerr5/2.2), alpha=0.3, color='red')

axs[2,1].set_xlim(0,66)
axs[2,2].plot(xxx6[0:58],yyy6[0:58], alpha=0.5, marker=".", lw=2, label='Act 8', color='red')
axs[2,2].fill_between(xxx6[0:58], yyy6[0:58]-(yyyerr6[0:58]/2.2), yyy6[0:58]+(yyyerr6[0:58]/2.2), alpha=0.3, color='red')
axs[2,2].set_xlabel('Residue')
axs[2,2].set_xlim(0,66)
axs[0,2].set_xlim(0,66)
axs[1,2].set_xlim(0,66)
axs[0,0].legend()
ax1 = axs[0,2].twinx()
ax1.set_yticks([])
ax1.set_ylabel('Monomer', rotation=270, labelpad=15)
ax1 = axs[1,2].twinx()
ax1.set_yticks([])
ax1.set_ylabel('Dimer Subunit', rotation=270, labelpad=15)
ax1 = axs[2,2].twinx()
ax1.set_yticks([])
ax1.set_ylabel('DNA-Bound', rotation=270, labelpad=15)
plt.suptitle('Cro Fluctuations')
plt.tight_layout()

plt.savefig('rmsf_fullvstrunc.pdf')

# %%
sxx1,syy1,syyerr1 = np.loadtxt("./RMSF/WTdim_sub2rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))
sxxx1,syyy1,syyyerr1 = np.loadtxt("./RMSF/WTdna_sub2rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))	


sxx2,syy2,syyerr2 = np.loadtxt("./RMSF/A3dim_sub2rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))	
sxxx2,syyy2,syyyerr2 = np.loadtxt("./RMSF/A3dna_sub2rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))	


sxx3,syy3,syyerr3 = np.loadtxt("./RMSF/A8dim_sub2rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))	
sxxx3,syyy3,syyyerr3 = np.loadtxt("./RMSF/A8dna_sub2rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))


sxx4,syy4,syyerr4 = np.loadtxt("./RMSF/WTrdim_sub2rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))	
sxxx4,syyy4,syyyerr4 = np.loadtxt("./RMSF/WTrdna_sub2rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))	


sxx5,syy5,syyerr5 = np.loadtxt("./RMSF/T3dim_sub2rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))	
sxxx5,syyy5,syyyerr5 = np.loadtxt("./RMSF/T3dna_sub2rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))	


sxx6,syy6,syyerr6 = np.loadtxt("./RMSF/T8dim_sub2rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))	
sxxx6,syyy6,syyyerr6 = np.loadtxt("./RMSF/T8dna_sub2rmsfavg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))

# %%
# SI - Full length subunit comparisons

fig, axs = plt.subplots(2,3, figsize=(6.5,4.5), sharey=True, sharex=True)

axs[0,0].plot(xx1,yy1, alpha=0.5, marker=".", lw=2, label='Subunit 1', color='blue')
axs[0,0].fill_between(xx1, yy1-(yyerr1/2.2), yy1+(yyerr1/2.2), alpha=0.3, color='blue')
axs[0,0].plot(sxx1,syy1, alpha=0.5, marker=".", lw=2, label='Subunit 2', color='orange')
axs[0,0].fill_between(sxx1, syy1-(syyerr1/2.2), syy1+(syyerr1/2.2), alpha=0.3, color='orange')
axs[0,0].set_title('Wild Type')
axs[0,0].set_ylabel('RMSF ($\AA$)')

axs[0,1].plot(xx2,yy2, alpha=0.5, marker=".", lw=2, label='Subunit 1', color='blue')
axs[0,1].fill_between(xx2, yy2-(yyerr2/2.2), yy2+(yyerr2/2.2), alpha=0.3, color='blue')
axs[0,1].plot(sxx2,syy2, alpha=0.5, marker=".", lw=2, label='Subunit 2', color='orange')
axs[0,1].fill_between(sxx2, syy2-(syyerr2/2.2), syy2+(syyerr2/2.2), alpha=0.3, color='orange')
axs[0,1].set_title('Act 3')

axs[0,2].plot(xx3,yy3, alpha=0.5, marker=".", lw=2, label='Subunit 1', color='blue')
axs[0,2].fill_between(xx3, yy3-(yyerr3/2.2), yy3+(yyerr3/2.2), alpha=0.3, color='blue')
axs[0,2].plot(sxx3,syy3, alpha=0.5, marker=".", lw=2, label='Subunit 2', color='orange')
axs[0,2].fill_between(sxx3, syy3-(syyerr3/2.2), syy3+(syyerr3/2.2), alpha=0.3, color='orange')
axs[0,2].set_title('Act 8')

axs[1,0].plot(xxx1,yyy1, alpha=0.5, marker=".", lw=2, label='Subunit 1', color='blue')
axs[1,0].fill_between(xxx1, yyy1-(yyyerr1/2.2), yyy1+(yyyerr1/2.2), alpha=0.3, color='blue')
axs[1,0].plot(sxxx1,syyy1, alpha=0.5, marker=".", lw=2, label='Subunit 2', color='orange')
axs[1,0].fill_between(sxxx1, syyy1-(syyyerr1/2.2), syyy1+(syyyerr1/2.2), alpha=0.3, color='orange')
axs[1,0].set_ylabel('RMSF ($\AA$)')
axs[1,0].set_xlabel('Residue')

axs[1,1].plot(xxx2,yyy2, alpha=0.5, marker=".", lw=2, label='Subunit 1', color='blue')
axs[1,1].fill_between(xxx2, yyy2-(yyyerr2/2.2), yyy2+(yyyerr2/2.2), alpha=0.3, color='blue')
axs[1,1].plot(sxxx2,syyy2, alpha=0.5, marker=".", lw=2, label='Subunit 2', color='orange')
axs[1,1].fill_between(sxxx2, syyy2-(syyyerr2/2.2), syyy2+(syyyerr2/2.2), alpha=0.3, color='orange')
axs[1,1].set_xlabel('Residue')

axs[1,2].plot(xxx3,yyy3, alpha=0.5, marker=".", lw=2, label='Subunit 1', color='blue')
axs[1,2].fill_between(xxx3, yyy3-(yyyerr3/2.2), yyy3+(yyyerr3/2.2), alpha=0.3, color='blue')
axs[1,2].plot(sxxx3,syyy3, alpha=0.5, marker=".", lw=2, label='Subunit 2', color='orange')
axs[1,2].fill_between(sxx3, syyy3-(syyyerr3/2.2), syyy3+(syyyerr3/2.2), alpha=0.3, color='orange')
axs[1,2].set_xlabel('Residue')

ax1 = axs[0,2].twinx()
ax1.set_yticks([])
ax1.set_ylabel('Dimer', rotation=270, labelpad=15)
ax1 = axs[1,2].twinx()
ax1.set_yticks([])
ax1.set_ylabel('DNA-Bound', rotation=270, labelpad=15)
#legend = axs[0, 1].legend(loc='upper left', bbox_to_anchor=(1.15, 1))
axs[0,0].legend()
plt.suptitle('Full Length Cro Dimer Fluctuations')
plt.tight_layout()

plt.savefig('rmsf_fullsubunits.pdf')

# %%
# SI - Truncated subunit comparisons

fig, axs = plt.subplots(2,3, figsize=(6.5,4.5), sharey=True, sharex=True)

axs[0,0].plot(xx4,yy4, alpha=0.5, marker=".", lw=2, label='Subunit 1', color='blue')
axs[0,0].fill_between(xx4, yy4-(yyerr4/2.2), yy4+(yyerr4/2.2), alpha=0.3, color='blue')
axs[0,0].plot(sxx4,syy4, alpha=0.5, marker=".", lw=2, label='Subunit 2', color='orange')
axs[0,0].fill_between(sxx4, syy4-(syyerr4/2.2), syy4+(syyerr4/2.2), alpha=0.3, color='orange')
axs[0,0].set_title('Wild Type')
axs[0,0].set_ylabel('RMSF ($\AA$)')

axs[0,1].plot(xx5,yy5, alpha=0.5, marker=".", lw=5, label='Subunit 1', color='blue')
axs[0,1].fill_between(xx5, yy5-(yyerr5/2.2), yy5+(yyerr5/2.2), alpha=0.3, color='blue')
axs[0,1].plot(sxx5,syy5, alpha=0.5, marker=".", lw=2, label='Subunit 2', color='orange')
axs[0,1].fill_between(sxx5, syy5-(syyerr5/2.2), syy5+(syyerr5/2.2), alpha=0.3, color='orange')
axs[0,1].set_title('Act 3')

axs[0,2].plot(xx6,yy6, alpha=0.5, marker=".", lw=2, label='Subunit 1', color='blue')
axs[0,2].fill_between(xx6, yy6-(yyerr6/2.2), yy6+(yyerr6/2.2), alpha=0.3, color='blue')
axs[0,2].plot(sxx6,syy6, alpha=0.5, marker=".", lw=2, label='Subunit 2', color='orange')
axs[0,2].fill_between(sxx6, syy6-(syyerr6/2.2), syy6+(syyerr6/2.2), alpha=0.3, color='orange')
axs[0,2].set_title('Act 8')

axs[1,0].plot(xxx4,yyy4, alpha=0.5, marker=".", lw=2, label='Subunit 1', color='blue')
axs[1,0].fill_between(xxx4, yyy4-(yyyerr4/2.2), yyy4+(yyyerr4/2.2), alpha=0.3, color='blue')
axs[1,0].plot(sxxx4,syyy4, alpha=0.5, marker=".", lw=2, label='Subunit 2', color='orange')
axs[1,0].fill_between(sxxx4, syyy4-(syyyerr4/2.2), syyy4+(syyyerr4/2.2), alpha=0.3, color='orange')
axs[1,0].set_ylabel('RMSF ($\AA$)')
axs[1,0].set_xlabel('Residue')

axs[1,1].plot(xxx5,yyy5, alpha=0.5, marker=".", lw=2, label='Subunit 1', color='blue')
axs[1,1].fill_between(xxx5, yyy5-(yyyerr5/2.2), yyy5+(yyyerr5/2.2), alpha=0.3, color='blue')
axs[1,1].plot(sxxx5,syyy5, alpha=0.5, marker=".", lw=2, label='Subunit 2', color='orange')
axs[1,1].fill_between(sxxx5, syyy5-(syyyerr5/2.2), syyy5+(syyyerr5/2.2), alpha=0.3, color='orange')
axs[1,1].set_xlabel('Residue')

axs[1,2].plot(xxx6,yyy6, alpha=0.5, marker=".", lw=2, label='Subunit 1', color='blue')
axs[1,2].fill_between(xxx6, yyy6-(yyyerr6/2.2), yyy6+(yyyerr6/2.2), alpha=0.3, color='blue')
axs[1,2].plot(sxxx6,syyy6, alpha=0.5, marker=".", lw=2, label='Subunit 2', color='orange')
axs[1,2].fill_between(sxx6, syyy6-(syyyerr6/2.2), syyy6+(syyyerr6/2.2), alpha=0.3, color='orange')
axs[1,2].set_xlabel('Residue')

ax1 = axs[0,2].twinx()
ax1.set_yticks([])
ax1.set_ylabel('Dimer', rotation=270, labelpad=15)
ax1 = axs[1,2].twinx()
ax1.set_yticks([])
ax1.set_ylabel('DNA-Bound', rotation=270, labelpad=15)
#legend = axs[0, 1].legend(loc='upper left', bbox_to_anchor=(1.15, 1))
axs[0,0].legend()
plt.suptitle('Truncated Cro Dimer Fluctuations')
plt.tight_layout()

plt.savefig('rmsf_truncsubunits.pdf')
