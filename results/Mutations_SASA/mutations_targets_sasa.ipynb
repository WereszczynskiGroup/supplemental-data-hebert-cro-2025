# %%
import matplotlib.pyplot as plt
import numpy as np

wt1,wt2,wt3,wt4 = np.loadtxt('WT_Mmutsasa.dat', usecols=(1,2,3,4), unpack=True, comments='#')
a31,a32,a33,a34 = np.loadtxt('A3_Mmutsasa.dat', usecols=(1,2,3,4), unpack=True, comments='#')
a81,a82,a83,a84 = np.loadtxt('A8_Mmutsasa.dat', usecols=(1,2,3,4), unpack=True, comments='#')

values = [wt1,wt2,wt3,wt4,a31,a32,a33,a34,a81,a82,a83,a84]

for i in values:
    for j in range(0,len(i)):
        if i[j]<0:
            i[j]=0
        else:
            i[j]=i[j]

# %%
fig,ax = plt.subplots(4,1, sharex=True, sharey=True, figsize=(6,6))

ax[0].hist(wt1, density=True, histtype='step', label='Wild Type', bins=250)
ax[0].hist(a31, density=True, histtype='step', label='Act3', bins=250)
ax[0].hist(a81, density=True, histtype='step', label='Act8', bins=250)
ax[0].legend()
ax[0].set_title('Residue 17 - THR to VAL and THR')
ax[0].set_xlim(0,200)
ax[1].hist(wt2, density=True, histtype='step', label='Wild Type', bins=250)
ax[1].hist(a32, density=True, histtype='step', label='Act3', bins=250)
ax[1].hist(a82, density=True, histtype='step', label='Act8', bins=250)
ax[1].set_title('Residue 21 - LYS to ALA and VAL')
ax[1].set_ylabel('Prob. Density')
ax[2].hist(wt3, density=True, histtype='step', label='Wild Type', bins=250)
ax[2].hist(a33, density=True, histtype='step', label='Act3', bins=250)
ax[2].hist(a83, density=True, histtype='step', label='Act8', bins=250)
ax[2].set_title('Residue 22 - ASP to GLU')

ax[3].hist(wt4, density=True, histtype='step', label='Wild Type', bins=250)
ax[3].hist(a34, density=True, histtype='step', label='Act3', bins=250)
ax[3].hist(a84, density=True, histtype='step', label='Act8', bins=250)
ax[3].set_title('Residue 26 - TYR to ASP')
ax[3].set_xlabel('SASA ($\AA^2$)')
fig.suptitle('SASA of Mutation Targets (Monomer Cro)')
plt.tight_layout()
plt.savefig('monomer_mutsasa.pdf')
print(f'Res 17 WT: {wt1.mean():.3f} +/- {wt1.std()/2.2:.3f} to A3: {a31.mean():.3f} +/- {a31.std()/2.2:.3f} and A8: {a81.mean():.3f} +/- {a81.std()/2.2:.3f}')
print(f'Res 21 WT: {wt2.mean():.3f} +/- {wt2.std()/2.2:.3f} to A3: {a32.mean():.3f} +/- {a32.std()/2.2:.3f} and A8: {a82.mean():.3f} +/- {a82.std()/2.2:.3f}')
print(f'Res 22 WT: {wt3.mean():.3f} +/- {wt3.std()/2.2:.3f} to A3: {a33.mean():.3f} +/- {a33.std()/2.2:.3f} and A8: {a83.mean():.3f} +/- {a83.std()/2.2:.3f}')
print(f'Res 26 WT: {wt4.mean():.3f} +/- {wt4.std()/2.2:.3f} to A3: {a34.mean():.3f} +/- {a34.std()/2.2:.3f} and A8: {a84.mean():.3f} +/- {a84.std()/2.2:.3f}')
# Out:
# Res 17 WT: 97.317 +/- 6.185 to A3: 109.401 +/- 5.123 and A8: 100.021 +/- 4.069
# Res 21 WT: 92.288 +/- 8.423 to A3: 73.729 +/- 3.107 and A8: 112.915 +/- 5.671
# Res 22 WT: 43.773 +/- 8.526 to A3: 93.265 +/- 11.350 and A8: 82.740 +/- 10.410
# Res 26 WT: 149.934 +/- 10.858 to A3: 97.111 +/- 6.748 and A8: 98.290 +/- 6.938

# %%
#incomplete

fig,ax = plt.subplots(4,1, sharex=True, sharey=True, figsize=(6,6))

ax[0].hist(wt1/163, density=True, histtype='step', label='Wild Type', bins=250, color='blue')
ax[0].hist(a31/165, density=True, histtype='step', label='Act3', bins=250, color='orange')
ax[0].hist(a81/163, density=True, histtype='step', label='Act8', bins=250, color='green')
ax[0].legend()
ax[0].set_title('Residue 17 - THR to VAL and THR')
ax[0].set_xlim(0,1)
ax[1].hist(wt2/230, density=True, histtype='step', label='Wild Type', bins=250, color='blue')
ax[1].hist(a32/121, density=True, histtype='step', label='Act3', bins=250, color='orange')
ax[1].hist(a82/165, density=True, histtype='step', label='Act8', bins=250, color='green')
ax[1].set_title('Residue 21 - LYS to ALA and VAL')
ax[1].set_ylabel('Prob. Density')
ax[2].hist(wt3/187, density=True, histtype='step', label='Wild Type', bins=250, color='blue')
ax[2].hist(a33/214, density=True, histtype='step', label='Act3', bins=250, color='orange')
ax[2].hist(a83/214, density=True, histtype='step', label='Act8', bins=250, color='green')
ax[2].set_title('Residue 22 - ASP to GLU')

ax[3].hist(wt4/255, density=True, histtype='step', label='Wild Type', bins=250, color='blue')
ax[3].hist(a34/187, density=True, histtype='step', label='Act3', bins=250, color='orange')
ax[3].hist(a84/187, density=True, histtype='step', label='Act8', bins=250, color='green')
ax[3].set_title('Residue 26 - TYR to ASP')
ax[3].set_xlabel('Proportion Exposed')
fig.suptitle('rSASA of Mutation Targets')
plt.tight_layout()
plt.savefig('monomer_mut_rsasa.pdf')
print(f'Res 17 WT: {wt1.mean()/163:.3f} +/- {wt1.std()/2.2/163:.3f} to A3: {a31.mean()/165:.3f} +/- {a31.std()/2.2/165:.3f} and A8: {a81.mean()/163:.3f} +/- {a81.std()/2.2/163:.3f}')
print(f'Res 21 WT: {wt2.mean()/230:.3f} +/- {wt2.std()/2.2/230:.3f} to A3: {a32.mean()/121:.3f} +/- {a32.std()/2.2/121:.3f} and A8: {a82.mean()/165:.3f} +/- {a82.std()/2.2/165:.3f}')
print(f'Res 22 WT: {wt3.mean()/187:.3f} +/- {wt3.std()/2.2/187:.3f} to A3: {a33.mean()/214:.3f} +/- {a33.std()/2.2/214:.3f} and A8: {a83.mean()/214:.3f} +/- {a83.std()/2.2/214:.3f}')
print(f'Res 26 WT: {wt4.mean()/255:.3f} +/- {wt4.std()/2.2/255:.3f} to A3: {a34.mean()/187:.3f} +/- {a34.std()/2.2/187:.3f} and A8: {a84.mean()/187:.3f} +/- {a84.std()/2.2/187:.3f}')
# Out:
# Res 17 WT: 0.597 +/- 0.038 to A3: 0.663 +/- 0.031 and A8: 0.614 +/- 0.025
# Res 21 WT: 0.401 +/- 0.037 to A3: 0.609 +/- 0.026 and A8: 0.684 +/- 0.034
# Res 22 WT: 0.234 +/- 0.046 to A3: 0.436 +/- 0.053 and A8: 0.387 +/- 0.049
# Res 26 WT: 0.588 +/- 0.043 to A3: 0.519 +/- 0.036 and A8: 0.526 +/- 0.037

# %%
import matplotlib.pyplot as plt
import numpy as np

wt1,wt2,wt3,wt4,wt5,wt6,wt7,wt8 = np.loadtxt('WTdimmutsasa.dat', usecols=(1,2,3,4,5,6,7,8), unpack=True, comments='#')
a31,a32,a33,a34,a35,a36,a37,a38 = np.loadtxt('A3dimmutsasa.dat', usecols=(1,2,3,4,5,6,7,8), unpack=True, comments='#')
a81,a82,a83,a84,a85,a86,a87,a88 = np.loadtxt('A8dimmutsasa.dat', usecols=(1,2,3,4,5,6,7,8), unpack=True, comments='#')

values = [wt1,wt2,wt3,wt4,a31,a32,a33,a34,a81,a82,a83,a84,wt5,wt6,wt7,wt8,a35,a36,a37,a38,a85,a86,a87,a88]

for i in values:
    for j in range(0,len(i)):
        if i[j]<0:
            i[j]=0
        else:
            i[j]=i[j]
            
fig,ax = plt.subplots(4,1, sharex=True, sharey=True, figsize=(6,6))

ax[0].hist(wt1, density=True, histtype='step', label='Wild Type', bins=250)
ax[0].hist(a31, density=True, histtype='step', label='Act3', bins=250)
ax[0].hist(a81, density=True, histtype='step', label='Act8', bins=250)
ax[0].legend()
ax[0].set_title('Residue 17 - THR to VAL and THR')

ax[1].hist(wt2, density=True, histtype='step', label='Wild Type', bins=250)
ax[1].hist(a32, density=True, histtype='step', label='Act3', bins=250)
ax[1].hist(a82, density=True, histtype='step', label='Act8', bins=250)
ax[1].set_title('Residue 21 - LYS to ALA and VAL')
ax[1].set_ylabel('Prob. Density')
ax[2].hist(wt3, density=True, histtype='step', label='Wild Type', bins=250)
ax[2].hist(a33, density=True, histtype='step', label='Act3', bins=250)
ax[2].hist(a83, density=True, histtype='step', label='Act8', bins=250)
ax[2].set_title('Residue 22 - ASP to GLU')

ax[3].hist(wt4, density=True, histtype='step', label='Wild Type', bins=250)
ax[3].hist(a34, density=True, histtype='step', label='Act3', bins=250)
ax[3].hist(a84, density=True, histtype='step', label='Act8', bins=250)
ax[3].set_title('Residue 26 - TYR to ASP')
ax[3].set_xlabel('SASA ($\AA^2$)')
fig.suptitle('SASA of Mutation Targets (Dimer Cro, Subunit 1)')
plt.tight_layout()
plt.savefig('dimersub1_mutsasa.pdf')

fig,ax = plt.subplots(4,1, sharex=True, sharey=True, figsize=(6,6))

ax[0].hist(wt5, density=True, histtype='step', label='Wild Type', bins=250)
ax[0].hist(a35, density=True, histtype='step', label='Act3', bins=250)
ax[0].hist(a85, density=True, histtype='step', label='Act8', bins=250)
ax[0].legend()
ax[0].set_title('Residue 17 - THR to VAL and THR')

ax[1].hist(wt6, density=True, histtype='step', label='Wild Type', bins=250)
ax[1].hist(a36, density=True, histtype='step', label='Act3', bins=250)
ax[1].hist(a86, density=True, histtype='step', label='Act8', bins=250)
ax[1].set_title('Residue 21 - LYS to ALA and VAL')
ax[1].set_ylabel('Prob. Density')
ax[2].hist(wt7, density=True, histtype='step', label='Wild Type', bins=250)
ax[2].hist(a37, density=True, histtype='step', label='Act3', bins=250)
ax[2].hist(a87, density=True, histtype='step', label='Act8', bins=250)
ax[2].set_title('Residue 22 - ASP to GLU')

ax[3].hist(wt8, density=True, histtype='step', label='Wild Type', bins=250)
ax[3].hist(a38, density=True, histtype='step', label='Act3', bins=250)
ax[3].hist(a88, density=True, histtype='step', label='Act8', bins=250)
ax[3].set_title('Residue 26 - TYR to ASP')
ax[3].set_xlabel('SASA ($\AA^2$)')
fig.suptitle('SASA of Mutation Targets (Dimer Cro, Subunit 2)')
plt.tight_layout()
plt.savefig('dimersub2_mutsasa.pdf')
print(f'Res 17 WT: {wt1.mean():.3f} +/- {wt1.std()/2.2:.3f} to A3: {a31.mean():.3f} +/- {a31.std()/2.2:.3f} and A8: {a81.mean():.3f} +/- {a81.std()/2.2:.3f}')
print(f'Res 21 WT: {wt2.mean():.3f} +/- {wt2.std()/2.2:.3f} to A3: {a32.mean():.3f} +/- {a32.std()/2.2:.3f} and A8: {a82.mean():.3f} +/- {a82.std()/2.2:.3f}')
print(f'Res 22 WT: {wt3.mean():.3f} +/- {wt3.std()/2.2:.3f} to A3: {a33.mean():.3f} +/- {a33.std()/2.2:.3f} and A8: {a83.mean():.3f} +/- {a83.std()/2.2:.3f}')
print(f'Res 26 WT: {wt4.mean():.3f} +/- {wt4.std()/2.2:.3f} to A3: {a34.mean():.3f} +/- {a34.std()/2.2:.3f} and A8: {a84.mean():.3f} +/- {a84.std()/2.2:.3f}')
# Out:
# Res 17 WT: 95.003 +/- 5.300 to A3: 110.197 +/- 3.742 and A8: 98.276 +/- 4.053
# Res 21 WT: 97.442 +/- 6.342 to A3: 73.559 +/- 2.421 and A8: 115.341 +/- 3.102
# Res 22 WT: 46.701 +/- 6.481 to A3: 86.316 +/- 8.577 and A8: 86.608 +/- 9.262
# Res 26 WT: 145.130 +/- 12.360 to A3: 95.868 +/- 6.870 and A8: 97.074 +/- 6.194

# %%
import matplotlib.pyplot as plt
import numpy as np

wt1,wt2,wt3,wt4,wt5,wt6,wt7,wt8 = np.loadtxt('WTdimmutsasa.dat', usecols=(1,2,3,4,5,6,7,8), unpack=True, comments='#')
a31,a32,a33,a34,a35,a36,a37,a38 = np.loadtxt('A3dimmutsasa.dat', usecols=(1,2,3,4,5,6,7,8), unpack=True, comments='#')
a81,a82,a83,a84,a85,a86,a87,a88 = np.loadtxt('A8dimmutsasa.dat', usecols=(1,2,3,4,5,6,7,8), unpack=True, comments='#')

values = [wt1,wt2,wt3,wt4,a31,a32,a33,a34,a81,a82,a83,a84,wt5,wt6,wt7,wt8,a35,a36,a37,a38,a85,a86,a87,a88]

for i in values:
    for j in range(0,len(i)):
        if i[j]<0:
            i[j]=0
        else:
            i[j]=i[j]
            
fig,ax = plt.subplots(4,1, sharex=True, sharey=True, figsize=(6,6))

ax[0].hist(wt1/163, density=True, histtype='step', label='Wild Type', bins=250)
ax[0].hist(a31/165, density=True, histtype='step', label='Act3', bins=250)
ax[0].hist(a81/163, density=True, histtype='step', label='Act8', bins=250)
ax[0].legend()
ax[0].set_title('Residue 17 - THR to VAL and THR')

ax[1].hist(wt2/230, density=True, histtype='step', label='Wild Type', bins=250)
ax[1].hist(a32/121, density=True, histtype='step', label='Act3', bins=250)
ax[1].hist(a82/165, density=True, histtype='step', label='Act8', bins=250)
ax[1].set_title('Residue 21 - LYS to ALA and VAL')
ax[1].set_ylabel('Prob. Density')
ax[2].hist(wt3/187, density=True, histtype='step', label='Wild Type', bins=250)
ax[2].hist(a33/214, density=True, histtype='step', label='Act3', bins=250)
ax[2].hist(a83/214, density=True, histtype='step', label='Act8', bins=250)
ax[2].set_title('Residue 22 - ASP to GLU')

ax[3].hist(wt4/255, density=True, histtype='step', label='Wild Type', bins=250)
ax[3].hist(a34/187, density=True, histtype='step', label='Act3', bins=250)
ax[3].hist(a84/187, density=True, histtype='step', label='Act8', bins=250)
ax[3].set_title('Residue 26 - TYR to ASP')
ax[3].set_xlabel('Proportion Exposed')
fig.suptitle('SASA of Mutation Targets (Dimer Cro, Subunit 1)')
plt.tight_layout()
plt.savefig('dimersub1_mut_rsasa.pdf')
fig,ax = plt.subplots(4,1, sharex=True, sharey=True, figsize=(6,6))

ax[0].hist(wt5/163, density=True, histtype='step', label='Wild Type', bins=250)
ax[0].hist(a35/165, density=True, histtype='step', label='Act3', bins=250)
ax[0].hist(a85/163, density=True, histtype='step', label='Act8', bins=250)
ax[0].legend()
ax[0].set_title('Residue 17 - THR to VAL and THR')

ax[1].hist(wt6/230, density=True, histtype='step', label='Wild Type', bins=250)
ax[1].hist(a36/121, density=True, histtype='step', label='Act3', bins=250)
ax[1].hist(a86/165, density=True, histtype='step', label='Act8', bins=250)
ax[1].set_title('Residue 21 - LYS to ALA and VAL')
ax[1].set_ylabel('Prob. Density')
ax[2].hist(wt7/187, density=True, histtype='step', label='Wild Type', bins=250)
ax[2].hist(a37/214, density=True, histtype='step', label='Act3', bins=250)
ax[2].hist(a87/214, density=True, histtype='step', label='Act8', bins=250)
ax[2].set_title('Residue 22 - ASP to GLU')

ax[3].hist(wt8/255, density=True, histtype='step', label='Wild Type', bins=250)
ax[3].hist(a38/187, density=True, histtype='step', label='Act3', bins=250)
ax[3].hist(a88/187, density=True, histtype='step', label='Act8', bins=250)
ax[3].set_title('Residue 26 - TYR to ASP')
ax[3].set_xlabel('Proportion Exposed')
fig.suptitle('rSASA of Mutation Targets (Dimer Cro, Subunit 2)')
plt.tight_layout()
plt.savefig('dimersub2_mut_rsasa.pdf')
print(f'Res 17 WT: {wt1.mean()/163:.3f} +/- {wt1.std()/2.2/163:.3f} to A3: {a31.mean()/165:.3f} +/- {a31.std()/2.2/165:.3f} and A8: {a81.mean()/163:.3f} +/- {a81.std()/2.2/163:.3f}')
print(f'Res 21 WT: {wt2.mean()/230:.3f} +/- {wt2.std()/2.2/230:.3f} to A3: {a32.mean()/121:.3f} +/- {a32.std()/2.2/121:.3f} and A8: {a82.mean()/165:.3f} +/- {a82.std()/2.2/165:.3f}')
print(f'Res 22 WT: {wt3.mean()/187:.3f} +/- {wt3.std()/2.2/187:.3f} to A3: {a33.mean()/214:.3f} +/- {a33.std()/2.2/214:.3f} and A8: {a83.mean()/214:.3f} +/- {a83.std()/2.2/214:.3f}')
print(f'Res 26 WT: {wt4.mean()/255:.3f} +/- {wt4.std()/2.2/255:.3f} to A3: {a34.mean()/187:.3f} +/- {a34.std()/2.2/187:.3f} and A8: {a84.mean()/187:.3f} +/- {a84.std()/2.2/187:.3f}')
# Out:
# Res 17 WT: 0.583 +/- 0.033 to A3: 0.668 +/- 0.023 and A8: 0.603 +/- 0.025
# Res 21 WT: 0.424 +/- 0.028 to A3: 0.608 +/- 0.020 and A8: 0.699 +/- 0.019
# Res 22 WT: 0.250 +/- 0.035 to A3: 0.403 +/- 0.040 and A8: 0.405 +/- 0.043
# Res 26 WT: 0.569 +/- 0.048 to A3: 0.513 +/- 0.037 and A8: 0.519 +/- 0.033

# %%
import matplotlib.pyplot as plt
import numpy as np

wt1,wt2,wt3,wt4,wt5,wt6,wt7,wt8 = np.loadtxt('WTdnamutsasa.dat', usecols=(1,2,3,4,5,6,7,8), unpack=True, comments='#')
a31,a32,a33,a34,a35,a36,a37,a38 = np.loadtxt('A3dnamutsasa.dat', usecols=(1,2,3,4,5,6,7,8), unpack=True, comments='#')
a81,a82,a83,a84,a85,a86,a87,a88 = np.loadtxt('A8dnamutsasa.dat', usecols=(1,2,3,4,5,6,7,8), unpack=True, comments='#')

values = [wt1,wt2,wt3,wt4,a31,a32,a33,a34,a81,a82,a83,a84,wt5,wt6,wt7,wt8,a35,a36,a37,a38,a85,a86,a87,a88]

for i in values:
    for j in range(0,len(i)):
        if i[j]<0:
            i[j]=0
        else:
            i[j]=i[j]
            
fig,ax = plt.subplots(4,1, sharex=True, sharey=True, figsize=(6,6))

ax[0].hist(wt1, density=True, histtype='step', label='Wild Type', bins=250)
ax[0].hist(a31, density=True, histtype='step', label='Act3', bins=250)
ax[0].hist(a81, density=True, histtype='step', label='Act8', bins=250)
ax[0].legend()
ax[0].set_title('Residue 17 - THR to VAL and THR')

ax[1].hist(wt2, density=True, histtype='step', label='Wild Type', bins=250)
ax[1].hist(a32, density=True, histtype='step', label='Act3', bins=250)
ax[1].hist(a82, density=True, histtype='step', label='Act8', bins=250)
ax[1].set_title('Residue 21 - LYS to ALA and VAL')
ax[1].set_ylabel('Prob. Density')
ax[2].hist(wt3, density=True, histtype='step', label='Wild Type', bins=250)
ax[2].hist(a33, density=True, histtype='step', label='Act3', bins=250)
ax[2].hist(a83, density=True, histtype='step', label='Act8', bins=250)
ax[2].set_title('Residue 22 - ASP to GLU')

ax[3].hist(wt4, density=True, histtype='step', label='Wild Type', bins=250)
ax[3].hist(a34, density=True, histtype='step', label='Act3', bins=250)
ax[3].hist(a84, density=True, histtype='step', label='Act8', bins=250)
ax[3].set_title('Residue 26 - TYR to ASP')
ax[3].set_xlabel('SASA ($\AA^2$)')
fig.suptitle('rSASA of Mutation Targets (DNA-bound Cro, Subunit 1)')
plt.tight_layout()
plt.savefig('dnasub1_mutsasa.pdf')

fig,ax = plt.subplots(4,1, sharex=True, sharey=True, figsize=(6,6))

ax[0].hist(wt5, density=True, histtype='step', label='Wild Type', bins=250)
ax[0].hist(a35, density=True, histtype='step', label='Act3', bins=250)
ax[0].hist(a85, density=True, histtype='step', label='Act8', bins=250)
ax[0].legend()
ax[0].set_title('Residue 17 - THR to VAL and THR')

ax[1].hist(wt6, density=True, histtype='step', label='Wild Type', bins=250)
ax[1].hist(a36, density=True, histtype='step', label='Act3', bins=250)
ax[1].hist(a86, density=True, histtype='step', label='Act8', bins=250)
ax[1].set_title('Residue 21 - LYS to ALA and VAL')
ax[1].set_ylabel('Prob. Density')
ax[2].hist(wt7, density=True, histtype='step', label='Wild Type', bins=250)
ax[2].hist(a37, density=True, histtype='step', label='Act3', bins=250)
ax[2].hist(a87, density=True, histtype='step', label='Act8', bins=250)
ax[2].set_title('Residue 22 - ASP to GLU')

ax[3].hist(wt8, density=True, histtype='step', label='Wild Type', bins=250)
ax[3].hist(a38, density=True, histtype='step', label='Act3', bins=250)
ax[3].hist(a88, density=True, histtype='step', label='Act8', bins=250)
ax[3].set_title('Residue 26 - TYR to ASP')
ax[3].set_xlabel('SASA ($\AA^2$)')
fig.suptitle('SASA of Mutation Targets (DNA-bound Cro, Subunit 2)')
plt.tight_layout()
plt.savefig('dnasub2_mutsasa.pdf')
print(f'Res 17 WT: {wt1.mean():.3f} +/- {wt1.std()/2.2:.3f} to A3: {a31.mean():.3f} +/- {a31.std()/2.2:.3f} and A8: {a81.mean():.3f} +/- {a81.std()/2.2:.3f}')
print(f'Res 21 WT: {wt2.mean():.3f} +/- {wt2.std()/2.2:.3f} to A3: {a32.mean():.3f} +/- {a32.std()/2.2:.3f} and A8: {a82.mean():.3f} +/- {a82.std()/2.2:.3f}')
print(f'Res 22 WT: {wt3.mean():.3f} +/- {wt3.std()/2.2:.3f} to A3: {a33.mean():.3f} +/- {a33.std()/2.2:.3f} and A8: {a83.mean():.3f} +/- {a83.std()/2.2:.3f}')
print(f'Res 26 WT: {wt4.mean():.3f} +/- {wt4.std()/2.2:.3f} to A3: {a34.mean():.3f} +/- {a34.std()/2.2:.3f} and A8: {a84.mean():.3f} +/- {a84.std()/2.2:.3f}')
# Out:
# Res 17 WT: 43.156 +/- 7.452 to A3: 93.514 +/- 5.562 and A8: 53.110 +/- 5.813
# Res 21 WT: 91.762 +/- 7.658 to A3: 73.963 +/- 2.564 and A8: 118.331 +/- 2.576
# Res 22 WT: 71.499 +/- 11.097 to A3: 90.971 +/- 8.876 and A8: 103.162 +/- 9.253
# Res 26 WT: 77.723 +/- 8.937 to A3: 44.594 +/- 8.778 and A8: 52.155 +/- 9.964

# %%
import matplotlib.pyplot as plt
import numpy as np

wt1,wt2,wt3,wt4,wt5,wt6,wt7,wt8 = np.loadtxt('WTdnamutsasa.dat', usecols=(1,2,3,4,5,6,7,8), unpack=True, comments='#')
a31,a32,a33,a34,a35,a36,a37,a38 = np.loadtxt('A3dnamutsasa.dat', usecols=(1,2,3,4,5,6,7,8), unpack=True, comments='#')
a81,a82,a83,a84,a85,a86,a87,a88 = np.loadtxt('A8dnamutsasa.dat', usecols=(1,2,3,4,5,6,7,8), unpack=True, comments='#')

values = [wt1,wt2,wt3,wt4,a31,a32,a33,a34,a81,a82,a83,a84,wt5,wt6,wt7,wt8,a35,a36,a37,a38,a85,a86,a87,a88]

for i in values:
    for j in range(0,len(i)):
        if i[j]<0:
            i[j]=0
        else:
            i[j]=i[j]
            
fig,ax = plt.subplots(4,1, sharex=True, sharey=True, figsize=(6,6))

ax[0].hist(wt1/163, density=True, histtype='step', label='Wild Type', bins=250)
ax[0].hist(a31/165, density=True, histtype='step', label='Act3', bins=250)
ax[0].hist(a81/163, density=True, histtype='step', label='Act8', bins=250)
ax[0].legend()
ax[0].set_title('Residue 17 - THR to VAL and THR')

ax[1].hist(wt2/230, density=True, histtype='step', label='Wild Type', bins=250)
ax[1].hist(a32/121, density=True, histtype='step', label='Act3', bins=250)
ax[1].hist(a82/165, density=True, histtype='step', label='Act8', bins=250)
ax[1].set_title('Residue 21 - LYS to ALA and VAL')
ax[1].set_ylabel('Prob. Density')
ax[2].hist(wt3/187, density=True, histtype='step', label='Wild Type', bins=250)
ax[2].hist(a33/214, density=True, histtype='step', label='Act3', bins=250)
ax[2].hist(a83/214, density=True, histtype='step', label='Act8', bins=250)
ax[2].set_title('Residue 22 - ASP to GLU')

ax[3].hist(wt4/255, density=True, histtype='step', label='Wild Type', bins=250)
ax[3].hist(a34/187, density=True, histtype='step', label='Act3', bins=250)
ax[3].hist(a84/187, density=True, histtype='step', label='Act8', bins=250)
ax[3].set_title('Residue 26 - TYR to ASP')
ax[3].set_xlabel('Proportion Exposed')
fig.suptitle('rSASA of Mutation Targets (DNA-bound Cro, Subunit 1)')
plt.tight_layout()
plt.savefig('dnasub1_mut_rsasa.pdf')

fig,ax = plt.subplots(4,1, sharex=True, sharey=True, figsize=(6,6))

ax[0].hist(wt5/163, density=True, histtype='step', label='Wild Type', bins=250)
ax[0].hist(a35/165, density=True, histtype='step', label='Act3', bins=250)
ax[0].hist(a85/163, density=True, histtype='step', label='Act8', bins=250)
ax[0].legend()
ax[0].set_title('Residue 17 - THR to VAL and THR')

ax[1].hist(wt6/230, density=True, histtype='step', label='Wild Type', bins=250)
ax[1].hist(a36/121, density=True, histtype='step', label='Act3', bins=250)
ax[1].hist(a86/165, density=True, histtype='step', label='Act8', bins=250)
ax[1].set_title('Residue 21 - LYS to ALA and VAL')
ax[1].set_ylabel('Prob. Density')
ax[2].hist(wt7/187, density=True, histtype='step', label='Wild Type', bins=250)
ax[2].hist(a37/214, density=True, histtype='step', label='Act3', bins=250)
ax[2].hist(a87/214, density=True, histtype='step', label='Act8', bins=250)
ax[2].set_title('Residue 22 - ASP to GLU')

ax[3].hist(wt8/255, density=True, histtype='step', label='Wild Type', bins=250)
ax[3].hist(a38/187, density=True, histtype='step', label='Act3', bins=250)
ax[3].hist(a88/187, density=True, histtype='step', label='Act8', bins=250)
ax[3].set_title('Residue 26 - TYR to ASP')
ax[3].set_xlabel('Proportion Exposed')
fig.suptitle('rSASA of Mutation Targets (DNA-bound Cro, Subunit 2)')
plt.tight_layout()
plt.savefig('dnasub2_mut_rsasa.pdf')
print(f'Res 17 WT: {wt1.mean()/163:.3f} +/- {wt1.std()/2.2/163:.3f} to A3: {a31.mean()/165:.3f} +/- {a31.std()/2.2/165:.3f} and A8: {a81.mean()/163:.3f} +/- {a81.std()/2.2/163:.3f}')
print(f'Res 21 WT: {wt2.mean()/230:.3f} +/- {wt2.std()/2.2/230:.3f} to A3: {a32.mean()/121:.3f} +/- {a32.std()/2.2/121:.3f} and A8: {a82.mean()/165:.3f} +/- {a82.std()/2.2/165:.3f}')
print(f'Res 22 WT: {wt3.mean()/187:.3f} +/- {wt3.std()/2.2/187:.3f} to A3: {a33.mean()/214:.3f} +/- {a33.std()/2.2/214:.3f} and A8: {a83.mean()/214:.3f} +/- {a83.std()/2.2/214:.3f}')
print(f'Res 26 WT: {wt4.mean()/255:.3f} +/- {wt4.std()/2.2/255:.3f} to A3: {a34.mean()/187:.3f} +/- {a34.std()/2.2/187:.3f} and A8: {a84.mean()/187:.3f} +/- {a84.std()/2.2/187:.3f}')
# Out:
# Res 17 WT: 0.265 +/- 0.046 to A3: 0.567 +/- 0.034 and A8: 0.326 +/- 0.036
# Res 21 WT: 0.399 +/- 0.033 to A3: 0.611 +/- 0.021 and A8: 0.717 +/- 0.016
# Res 22 WT: 0.382 +/- 0.059 to A3: 0.425 +/- 0.041 and A8: 0.482 +/- 0.043
# Res 26 WT: 0.305 +/- 0.035 to A3: 0.238 +/- 0.047 and A8: 0.279 +/- 0.053
